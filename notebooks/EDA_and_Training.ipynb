# %% [markdown]
# # Analisis Sentimen Marketplace Nasional 🇮🇩
#
# Notebook ini berisi langkah-langkah Eksplorasi Data (EDA) dan pelatihan model untuk analisis sentimen e-commerce berbahasa Indonesia.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('../data/raw/e-commerce-sampled-reviews.csv')
# df.head()

# %% [markdown]
# ## Preprocessing NLP

# %%
import sys
sys.path.append('../src')
from preprocess import preprocess_pipeline

# Preprocess sample
# sample_text = df['text'].head().tolist()
# print(preprocess_pipeline(sample_text))
